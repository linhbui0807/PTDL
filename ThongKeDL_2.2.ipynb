# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("updated_dataset.csv", sep =',')
data.head(15) #In ra dòng đầu để xem thử

#Tính toán thống kê tổng quan
data.describe(include='all')
# Out:
#          Customer ID        Purchase Date Product Category  Product Price  \
# count   250000.00000               250000           250000  250000.000000
# unique           NaN               234633                4            NaN
# top              NaN  2020-10-09 09:00:00         Clothing            NaN
# freq             NaN                    5            75052            NaN
# mean     25004.03624                  NaN              NaN     254.659512
# std      14428.27959                  NaN              NaN     141.568577
# min          1.00000                  NaN              NaN      10.000000
# 25%      12497.75000                  NaN              NaN     132.000000
# 50%      25018.00000                  NaN              NaN     255.000000
# 75%      37506.00000                  NaN              NaN     377.000000
# max      50000.00000                  NaN              NaN     500.000000
#
#              Quantity   Customer Age  Gender
# count   250000.000000  250000.000000  250000
# unique            NaN            NaN       2
# top               NaN            NaN  Female
# freq              NaN            NaN  125560
# mean         2.998896      43.940528     NaN
# std          1.414694      15.350246     NaN
# min          1.000000      18.000000     NaN
# 25%          2.000000      31.000000     NaN
# 50%          3.000000      44.000000     NaN
# 75%          4.000000      57.000000     NaN
# max          5.000000      70.000000     NaN

# %%
#Thống kê cho các cột kiểu dữ liệu chuỗi (object)
data.describe(include=['object'])
# Out:
#               Purchase Date Product Category  Gender
# count                250000           250000  250000
# unique               234633                4       2
# top     2020-10-09 09:00:00         Clothing  Female
# freq                      5            75052  125560
